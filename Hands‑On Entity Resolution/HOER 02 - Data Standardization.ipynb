# %% [markdown]
# # HOER 02 - Data Standardization

# %%
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

# After import you can jump to Step 2 if you wish to skip the data acquisition and use the data snapshot provided in the repo

# %% [markdown]
# ## Step 1 - Acquire Data

# %% [markdown]
# ### Wikipedia

# %%
# 1. Get the Wikipedia page (with User-Agent for robots policy)

url = "https://en.wikipedia.org/wiki/List_of_MPs_elected_in_the_2019_United_Kingdom_general_election"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
website_url = response.text

print(website_url[:300])    # Now should show real HTML, not robot policy
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1

# %%
# 2. Parse HTML and collect all tables

soup = BeautifulSoup(website_url, "html.parser")   # Parse HTML
tables = soup.find_all("table")                    # List of all <table> tags

print(f"Found {len(tables)} tables on the page.")
# Out:
# Found 12 tables on the page.

# %%
# 3. Find the MP table
#    First try phrase "Member returned"; if not found,
#    fall back to a table whose headers contain "Constituency" and "Member"

target_table = None

# Try by phrase
for table in tables:
    table_text = table.get_text(" ", strip=True)
    if "Member returned" in table_text:
        target_table = table
        break

# Fallback: by header structure
if target_table is None:
    for table in tables:
        th_texts = [th.get_text(strip=True) for th in table.find_all("th")]
        # Look for something that clearly looks like the MPs listing
        if "Constituency" in th_texts and any("Member" in h for h in th_texts):
            target_table = table
            break

if target_table is None:
    raise ValueError("Could not find a table with MP information.")

# %%
# 4. Extract headers and rows from the target table

# Get header cells
header_cells = target_table.find_all("th")
headers = [h.get_text(strip=True) for h in header_cells]

# Extract all data rows
rows = []
for tr in target_table.find_all("tr"):
    tds = tr.find_all("td")
    if not tds:
        continue
    row = [td.get_text(strip=True) for td in tds]
    rows.append(row)

# Make sure number of headers matches number of columns
max_cols = max(len(r) for r in rows) if rows else 0

if len(headers) > max_cols:
    headers = headers[:max_cols]
elif len(headers) < max_cols:
    headers = headers + [f"col_{i}" for i in range(len(headers), max_cols)]

# %%
# 5. Build the DataFrame

df_w = pd.DataFrame(rows, columns=headers)

df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Constituency              650 non-null    object
#  1   Affiliation of incumbent  650 non-null    object
#  2   Member returned           650 non-null    object
#  3   Notes                     650 non-null    object
#  4                             650 non-null    object
#  5   Affiliate                 650 non-null    object
#  6   Source:[24]               650 non-null    object
# dtypes: object(7)
# memory usage: 35.7+ KB

# %%
df_w.head()
# Out:
#          Constituency Affiliation of incumbent    Member returned  \
# 0            Aberavon                                      Labour
# 1           Aberconwy                                Conservative
# 2      Aberdeen North                           Scottish National
# 3      Aberdeen South                                Conservative
# 4  Airdrie and Shotts                           Scottish National
#
#              Notes            Affiliate                            Source:[24]
# 0  Stephen Kinnock               Labour                              Seat held
# 1     Robin Millar         Conservative     Incumbent,Guto Bebb, did not stand
# 2  Kirsty Blackman    Scottish National                              Seat held
# 3    Stephen Flynn    Scottish National  Incumbent,Ross Thomson, did not stand
# 4        Neil Gray    Scottish National                              Seat held

# %%
# Remove unwanted columns and check length

df_w = df_w[['Constituency','Member returned','Notes']]

df_w.head()
# Out:
#          Constituency    Member returned            Notes
# 0            Aberavon             Labour  Stephen Kinnock
# 1           Aberconwy       Conservative     Robin Millar
# 2      Aberdeen North  Scottish National  Kirsty Blackman
# 3      Aberdeen South       Conservative    Stephen Flynn
# 4  Airdrie and Shotts  Scottish National        Neil Gray

# %%
len(df_w)
# Out:
# 650

# %% [markdown]
# ### They Work For You

# %%
# Download all current Members of Parliament

url = "https://www.theyworkforyou.com/mps/?f=csv"
df_t = pd.read_csv(url, header=0)

df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Person ID     650 non-null    int64
#  1   First name    650 non-null    object
#  2   Last name     650 non-null    object
#  3   Party         650 non-null    object
#  4   Constituency  650 non-null    object
#  5   URI           650 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 30.6+ KB

# %%
df_t.head(n=5)
# Out:
#    Person ID First name Last name                Party  \
# 0      10001      Diane    Abbott          Independent
# 1      26385       Jack    Abbott  Labour/Co-operative
# 2      25034     Debbie  Abrahams               Labour
# 3      26364    Shockat      Adam          Independent
# 4      26483      Zubir     Ahmed               Labour
#
#                         Constituency  \
# 0  Hackney North and Stoke Newington
# 1                            Ipswich
# 2        Oldham East and Saddleworth
# 3                    Leicester South
# 4                 Glasgow South West
#
#                                                  URI
# 0  https://www.theyworkforyou.com/mp/10001/diane_...
# 1  https://www.theyworkforyou.com/mp/26385/jack_a...
# 2  https://www.theyworkforyou.com/mp/25034/debbie...
# 3  https://www.theyworkforyou.com/mp/26364/shocka...
# 4  https://www.theyworkforyou.com/mp/26483/zubir_...

# %% [markdown]
# ### Add facebook links

# %%
session = requests.Session()
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    )
}

def facelink(uri):
    try:
        resp = session.get(uri, headers=headers, timeout=3)
        if resp.status_code != 200:
            return ""
    except:
        return ""

    html = resp.text
    match = re.search(r'https?://(?:www\.)?facebook\.com/[^\s"\'<>]+',
                      html, flags=re.IGNORECASE)
    if match:
        link = match.group(0)
        if link.lower() != "https://facebook.com":
            return link
    return ""

# EXECUÇÃO PARALELA (20 threads)
with ThreadPoolExecutor(max_workers=20) as executor:
    results = list(executor.map(facelink, df_t["URI"]))

df_t["Flink"] = results
df_t["FullName"] = df_t["First name"] + " " + df_t["Last name"]

# Mostrar os que têm Facebook
print(df_t[df_t["Flink"] != ""][["FullName", "Flink"]].head(20))
# Out:
#              FullName                                              Flink
# 0        Diane Abbott                   https://facebook.com/Dianeabbott
# 10    Heidi Alexander  https://facebook.com/Heidi-Alexander-MP-460236...
# 11      Rushanara Ali     https://facebook.com/Rushanara-Ali-37684209618
# 13  Rosena Allin-Khan                      https://facebook.com/DrRosena
# 20      Stuart Andrew            https://facebook.com/StuartAndrewPudsey
# 21   Tonia Antoniazzi                 https://facebook.com/ToniaForGower
# 28    Victoria Atkins            https://facebook.com/VoteVictoriaAtkins
# 39   Harriett Baldwin               https://facebook.com/harriettbaldwin
# 42      Steve Barclay                https://facebook.com/stevebarclaymp
# 53        Hilary Benn       https://facebook.com/hilarybenn4leedscentral
# 56        Clive Betts       https://facebook.com/clive.betts.sheffieldse
# 60       Bob Blackman           https://facebook.com/bobblackmanofficial
# 61    Kirsty Blackman                 https://facebook.com/aberdeennorth
# 71      Karen Bradley              https://facebook.com/votekarenbradley
# 74   Suella Braverman       https://facebook.com/SuellaBravermanOfficial
# 78       Chris Bryant                 https://facebook.com/Chris4Rhondda
# 81     Richard Burgon     https://facebook.com/RichardBurgonForEastLeeds
# 84        Dawn Butler               https://facebook.com/DawnButlerBrent
# 86         Liam Byrne            https://facebook.com/LiamByrneHodgeHill
# 87       Ruth Cadbury            https://facebook.com/RuthCadburywin2017

# %% [markdown]
# ### Saving to Local Storage

# %%
# Save file to local storage
# Note uncommenting these lines will overwrite the repo snapshot and may result 
# in different values in this and subsequent chapters

#df_t.to_csv('mps_they_raw.csv', index=False)
#df_w.to_csv('mps_wiki_raw.csv')

# %% [markdown]
# ## Step 2 - Data Cleansing

# %%
# Theyworkforyou update their website after MP resignations, by-elections and general elections.

# To ensure consistency with the data at the time of writing the following statements overwrite
# the 'wiki' and 'they' raw dataframes with the snapshot provided in the repo

df_t = pd.read_csv('data/mps_they_raw.csv')
df_w = pd.read_csv('data/mps_wiki_raw.csv')

# %% [markdown]
# #### Wikipedia Data

# %%
df_w.head(n=5)
# Out:
#        Constituency    Member returned  \
# 0               NaN                NaN
# 1        Aberavon\n  Stephen Kinnock\n
# 2       Aberconwy\n     Robin Millar\n
# 3  Aberdeen North\n  Kirsty Blackman\n
# 4  Aberdeen South\n    Stephen Flynn\n
#
#                                                Notes
# 0                                                NaN
# 1                                        Seat held\n
# 2     Previous incumbent, Guto Bebb, did not stand\n
# 3                                        Seat held\n
# 4  Previous incumbent, Ross Thomson, did not stand\n

# %%
# Rename columns for consistency

df_w = df_w.rename(columns={ 'Member returned' : 'Fullname'})

# Remove null rows at start and end and strip tailing '\n'

df_w = df_w.dropna()
df_w['Constituency'] = df_w['Constituency'].str.rstrip("\n")
df_w['Fullname'] = df_w['Fullname'].str.rstrip("\n")

df_w.head(n=5)
# Out:
#          Constituency         Fullname  \
# 1            Aberavon  Stephen Kinnock
# 2           Aberconwy     Robin Millar
# 3      Aberdeen North  Kirsty Blackman
# 4      Aberdeen South    Stephen Flynn
# 5  Airdrie and Shotts        Neil Gray
#
#                                                Notes
# 1                                        Seat held\n
# 2     Previous incumbent, Guto Bebb, did not stand\n
# 3                                        Seat held\n
# 4  Previous incumbent, Ross Thomson, did not stand\n
# 5                                        Seat held\n

# %%
# Check \n not elsewhere in Fullname

df_w[df_w['Fullname'].astype(str).str.contains('\n')]
# Out:
#                    Constituency                  Fullname  \
# 228  Finchley and Golders Green              \nMike Freer
# 373                 Mole Valley          \nPaul Beresford
# 545                   Stockport          \nNavendu Mishra
# 546              Stockton North         \nAlex Cunningham
# 547              Stockton South            \nMatt Vickers
# ..                          ...                       ...
# 613          West Bromwich East         \nNicola Richards
# 614          West Bromwich West            \nShaun Bailey
# 616         West Dunbartonshire  \nMartin Docherty-Hughes
# 619                West Suffolk         \nMatthew Hancock
# 620                 West Tyrone        \nÓrfhlaith Begley
#
#                                                  Notes
# 228                                        Seat held\n
# 373                                        Seat held\n
# 545    Previous incumbent, Ann Coffey, did not stand\n
# 546                                        Seat held\n
# 547                Defeated incumbent, Paul Williams\n
# ..                                                 ...
# 613    Previous incumbent, Tom Watson, did not stand\n
# 614  Previous incumbent, Adrian Bailey, did not sta...
# 616                                        Seat held\n
# 619                                        Seat held\n
# 620                                        Seat held\n
#
# [75 rows x 3 columns]

# %%
# Strip leading '\n' 
df_w['Fullname'] = df_w['Fullname'].str.lstrip("\n")

# Check \n not elsewhere in Fullname
df_w[df_w['Fullname'].astype(str).str.contains('\n')]
# Out:
# Empty DataFrame
# Columns: [Constituency, Fullname, Notes]
# Index: []

# %%
# Check \n not elsewhere in Constituency
df_w[df_w['Constituency'].astype(str).str.contains('\n')]
# Out:
# Empty DataFrame
# Columns: [Constituency, Fullname, Notes]
# Index: []

# %%
df_w.head()
# Out:
#          Constituency         Fullname  \
# 1            Aberavon  Stephen Kinnock
# 2           Aberconwy     Robin Millar
# 3      Aberdeen North  Kirsty Blackman
# 4      Aberdeen South    Stephen Flynn
# 5  Airdrie and Shotts        Neil Gray
#
#                                                Notes
# 1                                        Seat held\n
# 2     Previous incumbent, Guto Bebb, did not stand\n
# 3                                        Seat held\n
# 4  Previous incumbent, Ross Thomson, did not stand\n
# 5                                        Seat held\n

# %%
# Split into Firstname and compound Lastname

df_w['Firstname'] = df_w['Fullname'].str.split().str[0]
df_w['Lastname'] = df_w['Fullname'].astype(str).apply(lambda x: ' '.join(x.split()[1:]))

df_w.head()
# Out:
#          Constituency         Fullname  \
# 1            Aberavon  Stephen Kinnock
# 2           Aberconwy     Robin Millar
# 3      Aberdeen North  Kirsty Blackman
# 4      Aberdeen South    Stephen Flynn
# 5  Airdrie and Shotts        Neil Gray
#
#                                                Notes Firstname  Lastname
# 1                                        Seat held\n   Stephen   Kinnock
# 2     Previous incumbent, Guto Bebb, did not stand\n     Robin    Millar
# 3                                        Seat held\n    Kirsty  Blackman
# 4  Previous incumbent, Ross Thomson, did not stand\n   Stephen     Flynn
# 5                                        Seat held\n      Neil      Gray

# %%
# Check for compound lastnames

df_w[df_w['Lastname'].astype(str).str.contains(' ')]['Lastname']
# Out:
# 31       de Cordova
# 134    Duncan Smith
# 393    Marie Morris
# 592      Ahmad Khan
# Name: Lastname, dtype: object

# %%
df_w.head()
# Out:
#          Constituency         Fullname  \
# 1            Aberavon  Stephen Kinnock
# 2           Aberconwy     Robin Millar
# 3      Aberdeen North  Kirsty Blackman
# 4      Aberdeen South    Stephen Flynn
# 5  Airdrie and Shotts        Neil Gray
#
#                                                Notes Firstname  Lastname
# 1                                        Seat held\n   Stephen   Kinnock
# 2     Previous incumbent, Guto Bebb, did not stand\n     Robin    Millar
# 3                                        Seat held\n    Kirsty  Blackman
# 4  Previous incumbent, Ross Thomson, did not stand\n   Stephen     Flynn
# 5                                        Seat held\n      Neil      Gray

# %% [markdown]
# #### They Work for You Data

# %%
df_t = df_t.rename(columns={'Last name' : 'Lastname', 'First name' : 'Firstname'})

df_t.head()
# Out:
#                         Constituency Firstname  Lastname  \
# 0  Hackney North and Stoke Newington     Diane    Abbott
# 1        Oldham East and Saddleworth    Debbie  Abrahams
# 2                   Selby and Ainsty     Nigel     Adams
# 3              Hitchin and Harpenden       Bim   Afolami
# 4                            Windsor      Adam   Afriyie
#
#                                       Flink
# 0          https://facebook.com/Dianeabbott
# 1                                       NaN
# 2        https://facebook.com/nigel.adamsmp
# 3                                       NaN
# 4  https://facebook.com/adamafriyieofficial

# %% [markdown]
# ### Calculate Exact Match Counts

# %%
len(df_w)
# Out:
# 650

# %%
len(df_t)
# Out:
# 650

# %%
# All matching columns for a merge (inner join) between two DataFrames: df_w and df_t.
# Merge only when all three columns match exactly in both DataFrames.
len(df_w.merge(df_t, on=['Constituency','Firstname','Lastname']))
# Out:
# 599

# %%
# Merge only when 'Constituency' and 'Lastname' columns match exactly in both DataFrames.
len(df_w.merge(df_t, on=['Constituency','Lastname']))
# Out:
# 607

# %%
# Merge only when First name and Last name columns match exactly in both DataFrames.
len(df_w.merge(df_t, on=['Firstname','Lastname'] ))
# Out:
# 624

# %%
# Match on Consistency and Last name
len(df_w.merge(df_t, on=['Constituency','Lastname'] ))
# Out:
# 607

# %%
# Match on Consistency and First name
len(df_w.merge(df_t, on=['Constituency','Firstname'] ))
# Out:
# 602

# %%
# Match on Lastname
len(df_w.merge(df_t, on=['Lastname'] ))
# Out:
# 982

# %%
# Match on Firstname
len(df_w.merge(df_t, on=['Firstname'] ))
# Out:
# 2663

# %%
# Match on Consistency
len(df_w.merge(df_t, on=['Constituency'] ))
# Out:
# 623

# %% [markdown]
# ## Step 3 - Further Cleansing

# %% [markdown]
# ### Constituency

# %%
# Perform an outer join on 'Constituency' and add a column showing the source of each row
df_w_outer = df_w.merge(df_t, on=['Constituency'],how="outer",indicator=True)

df_w_outer.head(3)
# Out:
#      Constituency         Fullname  \
# 0        Aberavon  Stephen Kinnock
# 1       Aberconwy     Robin Millar
# 2  Aberdeen North  Kirsty Blackman
#
#                                             Notes Firstname_x Lastname_x  \
# 0                                     Seat held\n     Stephen    Kinnock
# 1  Previous incumbent, Guto Bebb, did not stand\n       Robin     Millar
# 2                                     Seat held\n      Kirsty   Blackman
#
#   Firstname_y Lastname_y                                Flink _merge
# 0     Stephen    Kinnock  https://facebook.com/stephenkinnock   both
# 1       Robin     Millar                                  NaN   both
# 2      Kirsty   Blackman   https://facebook.com/aberdeennorth   both

# %%
# Show the first 5 constituencies that exist only in df_t (right side of the outer join)
df_w_outer[df_w_outer['_merge']=='right_only']['Constituency'].head(n=5)
# Out:
# 55     Birmingham, Edgbaston
# 56     Birmingham, Erdington
# 57    Birmingham, Hall Green
# 58    Birmingham, Hodge Hill
# 59      Birmingham, Ladywood
# Name: Constituency, dtype: object

# %%
# Show the first 5 constituencies that exist only in df_t (left side of the outer join)
df_w_outer[df_w_outer['_merge']=='left_only']['Constituency'].head(n=5)
# Out:
# 46     Birmingham Edgbaston
# 47     Birmingham Erdington
# 48    Birmingham Hall Green
# 49    Birmingham Hodge Hill
# 50      Birmingham Ladywood
# Name: Constituency, dtype: object

# %%
df_t.head(3)
# Out:
#                         Constituency Firstname  Lastname  \
# 0  Hackney North and Stoke Newington     Diane    Abbott
# 1        Oldham East and Saddleworth    Debbie  Abrahams
# 2                   Selby and Ainsty     Nigel     Adams
#
#                                 Flink
# 0    https://facebook.com/Dianeabbott
# 1                                 NaN
# 2  https://facebook.com/nigel.adamsmp

# %%
# Remove commas from both dataframes

df_t['Constituency'] = df_t['Constituency'].str.replace(',', '')
df_w['Constituency'] = df_w['Constituency'].str.replace(',', '')

# %%
# Match on Consistency

len(df_w.merge(df_t, on=['Constituency']))
# Out:
# 650

# %%
# Repeat perfect match count

len(df_w.merge(df_t, on=['Constituency','Firstname','Lastname']))
# Out:
# 624

# %% [markdown]
# ### Firstname

# %%
# Merge df_w and df_t on 'Constituency', keeping both versions of overlapping columns with suffixes
df_w_inner = df_w.merge(df_t, on=['Constituency'], suffixes=('_w', '_t'))

df_w_inner.head()
# Out:
#          Constituency         Fullname  \
# 0            Aberavon  Stephen Kinnock
# 1           Aberconwy     Robin Millar
# 2      Aberdeen North  Kirsty Blackman
# 3      Aberdeen South    Stephen Flynn
# 4  Airdrie and Shotts        Neil Gray
#
#                                                Notes Firstname_w Lastname_w  \
# 0                                        Seat held\n     Stephen    Kinnock
# 1     Previous incumbent, Guto Bebb, did not stand\n       Robin     Millar
# 2                                        Seat held\n      Kirsty   Blackman
# 3  Previous incumbent, Ross Thomson, did not stand\n     Stephen      Flynn
# 4                                        Seat held\n        Neil       Gray
#
#   Firstname_t Lastname_t                                Flink
# 0     Stephen    Kinnock  https://facebook.com/stephenkinnock
# 1       Robin     Millar                                  NaN
# 2      Kirsty   Blackman   https://facebook.com/aberdeennorth
# 3     Stephen      Flynn                                  NaN
# 4        Anum     Qaisar                                  NaN

# %%
# Filter rows where both the first names and last names differ between the two merged datasets
df_w_inner[(df_w_inner['Firstname_w'] != df_w_inner['Firstname_t']) &
           (df_w_inner['Lastname_w'] != df_w_inner['Lastname_t'])]
# Out:
#               Constituency           Fullname  \
# 4       Airdrie and Shotts          Neil Gray
# 29         Batley and Spen       Tracy Brabin
# 47    Birmingham Erdington        Jack Dromey
# 130   Chesham and Amersham      Cheryl Gillan
# 139        City of Chester     Chris Matheson
# 268             Hartlepool          Mike Hill
# 392           Newton Abbot  Anne Marie Morris
# 410       North Shropshire      Owen Paterson
# 432  Old Bexley and Sidcup  James Brokenshire
# 531          Southend West        David Amess
# 555  Stretford and Urmston         Kate Green
# 574   Tiverton and Honiton        Neil Parish
# 591              Wakefield   Imran Ahmad Khan
# 617        West Lancashire       Rosie Cooper
#
#                                  Notes Firstname_w    Lastname_w Firstname_t  \
# 4                          Seat held\n        Neil          Gray        Anum
# 29                         Seat held\n       Tracy        Brabin         Kim
# 47                         Seat held\n        Jack        Dromey    Paulette
# 130                        Seat held\n      Cheryl        Gillan       Sarah
# 139                        Seat held\n       Chris      Matheson    Samantha
# 268                        Seat held\n        Mike          Hill        Jill
# 392                        Seat held\n        Anne  Marie Morris  Anne Marie
# 410                        Seat held\n        Owen      Paterson       Helen
# 432                        Seat held\n       James   Brokenshire       Louie
# 531                        Seat held\n       David         Amess        Anna
# 555                        Seat held\n        Kate         Green      Andrew
# 574                        Seat held\n        Neil        Parish     Richard
# 591  Defeated incumbent, Mary Creagh\n       Imran    Ahmad Khan       Simon
# 617                        Seat held\n       Rosie        Cooper      Ashley
#
#      Lastname_t                                     Flink
# 4        Qaisar                                       NaN
# 29   Leadbeater                                       NaN
# 47     Hamilton                                       NaN
# 130       Green                                       NaN
# 139       Dixon                                       NaN
# 268    Mortimer                                       NaN
# 392      Morris  https://facebook.com/annemarie.morris.NA
# 410      Morgan                                       NaN
# 432      French                                       NaN
# 531       Firth                                       NaN
# 555     Western                                       NaN
# 574       Foord                                       NaN
# 591   Lightwood                                       NaN
# 617      Dalton                                       NaN

# %%
df_w_inner.head(3)
# Out:
#      Constituency         Fullname  \
# 0        Aberavon  Stephen Kinnock
# 1       Aberconwy     Robin Millar
# 2  Aberdeen North  Kirsty Blackman
#
#                                             Notes Firstname_w Lastname_w  \
# 0                                     Seat held\n     Stephen    Kinnock
# 1  Previous incumbent, Guto Bebb, did not stand\n       Robin     Millar
# 2                                     Seat held\n      Kirsty   Blackman
#
#   Firstname_t Lastname_t                                Flink
# 0     Stephen    Kinnock  https://facebook.com/stephenkinnock
# 1       Robin     Millar                                  NaN
# 2      Kirsty   Blackman   https://facebook.com/aberdeennorth

# %%
# Merge df_w and df_t on 'Constituency', appending suffixes to distinguish columns coming from each DataFrame
df_w_inner = df_w.merge(df_t, on=['Constituency'], suffixes=('_w', '_t'))

df_w_inner.head(3)
# Out:
#      Constituency         Fullname  \
# 0        Aberavon  Stephen Kinnock
# 1       Aberconwy     Robin Millar
# 2  Aberdeen North  Kirsty Blackman
#
#                                             Notes Firstname_w Lastname_w  \
# 0                                     Seat held\n     Stephen    Kinnock
# 1  Previous incumbent, Guto Bebb, did not stand\n       Robin     Millar
# 2                                     Seat held\n      Kirsty   Blackman
#
#   Firstname_t Lastname_t                                Flink
# 0     Stephen    Kinnock  https://facebook.com/stephenkinnock
# 1       Robin     Millar                                  NaN
# 2      Kirsty   Blackman   https://facebook.com/aberdeennorth

# %%
# Filter rows where exactly one field (Firstname or Lastname) matches between df_w and df_t,
# meaning either Firstname matches but Lastname differs, or Lastname matches but Firstname differs
df_w_inner[
    (df_w_inner['Firstname_w'] == df_w_inner['Firstname_t']) & (df_w_inner['Lastname_w'] != df_w_inner['Lastname_t']) |
    (df_w_inner['Firstname_w'] != df_w_inner['Firstname_t']) & (df_w_inner['Lastname_w'] == df_w_inner['Lastname_t'])
]
# Out:
#                           Constituency                Fullname  \
# 46                Birmingham Edgbaston              Preet Gill
# 99                              Burton          Kate Griffiths
# 122  Central Suffolk and North Ipswich             Dan Poulter
# 272               Hayes and Harlington          John McDonnell
# 311           Kingston upon Hull North           Diana Johnson
# 316                       Lagan Valley       Jeffrey Donaldson
# 394                       North Antrim             Ian Paisley
# 502                             Slough        Tanmanjeet Dhesi
# 510                         South Down           Chris Hazzard
# 526                 South West Norfolk               Liz Truss
# 605                            Wealden               Nus Ghani
# 615                West Dunbartonshire  Martin Docherty-Hughes
#
#                                                  Notes Firstname_w  \
# 46                                         Seat held\n       Preet
# 99   Previous incumbent, Andrew Griffiths, did not ...        Kate
# 122                                        Seat held\n         Dan
# 272                                        Seat held\n        John
# 311                                        Seat held\n       Diana
# 316                                        Seat held\n     Jeffrey
# 394                                        Seat held\n         Ian
# 502                                        Seat held\n  Tanmanjeet
# 510                                        Seat held\n       Chris
# 526                                        Seat held\n         Liz
# 605                                        Seat held\n         Nus
# 615                                        Seat held\n      Martin
#
#           Lastname_w  Firstname_t   Lastname_t  \
# 46              Gill   Preet Kaur         Gill
# 99         Griffiths         Kate     Kniveton
# 122          Poulter       Daniel      Poulter
# 272        McDonnell  John Martin    McDonnell
# 311          Johnson     Diana R.      Johnson
# 316        Donaldson   Jeffrey M.    Donaldson
# 394          Paisley          Ian  Paisley Jnr
# 502            Dhesi          Tan        Dhesi
# 510          Hazzard  Christopher      Hazzard
# 526            Truss    Elizabeth        Truss
# 605            Ghani       Nusrat        Ghani
# 615  Docherty-Hughes       Martin     Docherty
#
#                                             Flink
# 46           https://facebook.com/PreetKaurGillMP
# 99                                            NaN
# 122                                           NaN
# 272          https://facebook.com/johnmcdonnellmp
# 311    https://facebook.com/DianaJohnsonHullNorth
# 316       https://facebook.com/jeffrey.donaldson1
# 394                                           NaN
# 502                 https://facebook.com/tandhesi
# 510         https://facebook.com/chris.hazzard.77
# 526  https://facebook.com/ElizabethTrussSWNorfolk
# 605         https://facebook.com/NusGhaniofficial
# 615        https://facebook.com/MartinDochertySNP

# %%
df_t.head(3)
# Out:
#                         Constituency Firstname  Lastname  \
# 0  Hackney North and Stoke Newington     Diane    Abbott
# 1        Oldham East and Saddleworth    Debbie  Abrahams
# 2                   Selby and Ainsty     Nigel     Adams
#
#                                 Flink
# 0    https://facebook.com/Dianeabbott
# 1                                 NaN
# 2  https://facebook.com/nigel.adamsmp

# %%
# Extract the first word from the 'Firstname' column in df_t (useful when names contain multiple parts)
df_t['Firstname'] = df_t['Firstname'].str.split().str[0]

df_t.head(3)
# Out:
#                         Constituency Firstname  Lastname  \
# 0  Hackney North and Stoke Newington     Diane    Abbott
# 1        Oldham East and Saddleworth    Debbie  Abrahams
# 2                   Selby and Ainsty     Nigel     Adams
#
#                                 Flink
# 0    https://facebook.com/Dianeabbott
# 1                                 NaN
# 2  https://facebook.com/nigel.adamsmp

# %%
# Final resolved match count
df_resolved = df_w.merge(df_t, on=['Firstname','Lastname'] )
len(df_resolved)
# Out:
# 628

# %%
# Merge df_w and df_t on 'Constituency', keeping duplicated column names separate using suffixes
df_w_inner = df_w.merge(df_t, on=['Constituency'], suffixes=('_w', '_t'))

# Select rows where exactly one of the name fields matches (Firstname or Lastname), 
# identifying partial mismatches between the two datasets
df_w_unmatched = df_w_inner[
    (df_w_inner['Firstname_w'] == df_w_inner['Firstname_t']) & (df_w_inner['Lastname_w'] != df_w_inner['Lastname_t']) |
    (df_w_inner['Firstname_w'] != df_w_inner['Firstname_t']) & (df_w_inner['Lastname_w'] == df_w_inner['Lastname_t'])
]

df_w_unmatched
# Out:
#                           Constituency                Fullname  \
# 99                              Burton          Kate Griffiths
# 122  Central Suffolk and North Ipswich             Dan Poulter
# 392                       Newton Abbot       Anne Marie Morris
# 394                       North Antrim             Ian Paisley
# 502                             Slough        Tanmanjeet Dhesi
# 510                         South Down           Chris Hazzard
# 526                 South West Norfolk               Liz Truss
# 605                            Wealden               Nus Ghani
# 615                West Dunbartonshire  Martin Docherty-Hughes
#
#                                                  Notes Firstname_w  \
# 99   Previous incumbent, Andrew Griffiths, did not ...        Kate
# 122                                        Seat held\n         Dan
# 392                                        Seat held\n        Anne
# 394                                        Seat held\n         Ian
# 502                                        Seat held\n  Tanmanjeet
# 510                                        Seat held\n       Chris
# 526                                        Seat held\n         Liz
# 605                                        Seat held\n         Nus
# 615                                        Seat held\n      Martin
#
#           Lastname_w  Firstname_t   Lastname_t  \
# 99         Griffiths         Kate     Kniveton
# 122          Poulter       Daniel      Poulter
# 392     Marie Morris         Anne       Morris
# 394          Paisley          Ian  Paisley Jnr
# 502            Dhesi          Tan        Dhesi
# 510          Hazzard  Christopher      Hazzard
# 526            Truss    Elizabeth        Truss
# 605            Ghani       Nusrat        Ghani
# 615  Docherty-Hughes       Martin     Docherty
#
#                                             Flink
# 99                                            NaN
# 122                                           NaN
# 392      https://facebook.com/annemarie.morris.NA
# 394                                           NaN
# 502                 https://facebook.com/tandhesi
# 510         https://facebook.com/chris.hazzard.77
# 526  https://facebook.com/ElizabethTrussSWNorfolk
# 605         https://facebook.com/NusGhaniofficial
# 615        https://facebook.com/MartinDochertySNP

# %% [markdown]
# ## Sample Problem: Find MPs who held their seat and currently have Facebook account

# %%
df_resolved.head(n=5)
# Out:
#    Constituency_x         Fullname  \
# 0        Aberavon  Stephen Kinnock
# 1       Aberconwy     Robin Millar
# 2  Aberdeen North  Kirsty Blackman
# 3  Aberdeen South    Stephen Flynn
# 4       Aldershot     Leo Docherty
#
#                                                Notes Firstname  Lastname  \
# 0                                        Seat held\n   Stephen   Kinnock
# 1     Previous incumbent, Guto Bebb, did not stand\n     Robin    Millar
# 2                                        Seat held\n    Kirsty  Blackman
# 3  Previous incumbent, Ross Thomson, did not stand\n   Stephen     Flynn
# 4                                        Seat held\n       Leo  Docherty
#
#    Constituency_y                                          Flink
# 0        Aberavon            https://facebook.com/stephenkinnock
# 1       Aberconwy                                            NaN
# 2  Aberdeen North             https://facebook.com/aberdeennorth
# 3  Aberdeen South                                            NaN
# 4       Aldershot  https://facebook.com/pg/LeoDocherty4Aldershot

# %%
# Select those records with a non-null Facebook reference

# Filter rows where 'Flink' is not empty and 'Notes' is exactly "Seat held\n"
df_heldwithface = df_resolved[(df_resolved['Flink']!="") & (df_resolved['Notes']=="Seat held\n")]
len(df_heldwithface)
# Out:
# 474

# %% [markdown]
# ## Save Files for Subsequent Chapters

# %%
# Save file to local storage
# Note uncommenting these lines will overwrite the repo snapshot and may result 
# in different values in this and subsequent chapters

# Save unmatched to pick up in Chapter 3

df_w_unmatched.to_csv('data/mps_unmatched.csv', index=False)

df_w.to_csv('data/mps_wiki_clean.csv', index=False)
df_t.to_csv('data/mps_they_clean.csv', index=False)
